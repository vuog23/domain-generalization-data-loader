# %%
import os
os.chdir('..')

# %%
from src.data.loaders import make_domainbed_loaders

# %%
source_train_loaders, source_val_loaders, test_loader, class_to_idx, source_env_names = make_domainbed_loaders(
    root_path=r"D:\Project\CPV_paper\datasets\processed\NICOPP",
    target_domain_group="autumn_rock",
    source_domain_groups=None,
    source_splits=("train", "test"),
    target_splits=("train", "test"),
    train_transform=None,
    eval_transform=None,
    batch_size=32,
    val_ratio=0.2,
    seed=42,
    num_workers=2,
)
# Out:
# Source env 0: dim_grass/dim | train=9992, val=2497, batch_size=32
# Source env 1: dim_grass/grass | train=16262, val=4065, batch_size=32
# Source env 2: outdoor_water/outdoor | train=13352, val=3338, batch_size=32
# Source env 3: outdoor_water/water | train=15362, val=3840, batch_size=32
#
# Final DomainBed-style loaders:
# Number of source envs: 4
# Batch size per env:    32
# Total train batch:     128
# Target test size:      20158
# Num classes:           60
# Target group:          autumn_rock
# Source envs:           ['dim_grass/dim', 'dim_grass/grass', 'outdoor_water/outdoor', 'outdoor_water/water']
